# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\gudap\OneDrive\Desktop\RAINFALL_PREDICTION\Data Collection\Weather.csv")

# %%
y=data['RainTomorrow']
x=data.drop('RainTomorrow',axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
names=x.columns

# %%
names
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', '@dropdown'],
#       dtype='object')

# %%
sc=StandardScaler()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# Use .fillna('Unknown') temporarily to allow LabelEncoder to process NaN
data['RainTomorrow_Encoded'] = le.fit_transform(data['RainTomorrow'].astype(str))

df_processed = data.drop(columns=['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow', '@dropdown'])

for col in df_processed.columns:
    if df_processed[col].isnull().any():
        df_processed[col] = df_processed[col].fillna(df_processed[col].median())

# Now, 'x' should contain only numeric data
x = df_processed.drop(columns=['RainTomorrow_Encoded']).values
y = df_processed['RainTomorrow_Encoded'].values

# %%
len(names)          # check
names = names[:16] # or otherwise correct it
x = pd.DataFrame(x, columns=names)

# %%
print(x)
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       13.4      22.9      0.6      4.8       8.4         44.0      20.0
# 1        7.4      25.1      0.0      4.8       8.4         44.0       4.0
# 2       12.9      25.7      0.0      4.8       8.4         46.0      19.0
# 3        9.2      28.0      0.0      4.8       8.4         24.0      11.0
# 4       17.5      32.3      1.0      4.8       8.4         41.0       7.0
# ...      ...       ...      ...      ...       ...          ...       ...
# 145455   2.8      23.4      0.0      4.8       8.4         31.0      13.0
# 145456   3.6      25.3      0.0      4.8       8.4         22.0      13.0
# 145457   5.4      26.9      0.0      4.8       8.4         37.0       9.0
# 145458   7.8      27.0      0.0      4.8       8.4         28.0      13.0
# 145459  14.9      22.6      0.0      4.8       8.4         39.0      17.0
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 0              24.0           71.0        22.0      1007.7        1007.1
# 1              22.0           44.0        25.0      1010.6        1007.8
# 2              26.0           38.0        30.0      1007.6        1008.7
# 3               9.0           45.0        16.0      1017.6        1012.8
# 4              20.0           82.0        33.0      1010.8        1006.0
# ...             ...            ...         ...         ...           ...
# 145455         11.0           51.0        24.0      1024.6        1020.3
# 145456          9.0           56.0        21.0      1023.5        1019.1
# 145457          9.0           53.0        24.0      1021.0        1016.8
# 145458          7.0           51.0        24.0      1019.4        1016.5
# 145459         17.0           62.0        36.0      1020.2        1017.9
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am
# 0                8.0          5.0         16.9         21.8
# 1                5.0          5.0         17.2         24.3
# 2                5.0          2.0         21.0         23.2
# 3                5.0          5.0         18.1         26.5
# 4                7.0          8.0         17.8         29.7
# ...              ...          ...          ...          ...
# 145455           5.0          5.0         10.1         22.4
# 145456           5.0          5.0         10.9         24.5
# 145457           5.0          5.0         12.5         26.1
# 145458           3.0          2.0         15.1         26.0
# 145459           8.0          8.0         15.0         20.9
#
# [145460 rows x 16 columns]
